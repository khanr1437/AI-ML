# %% [markdown]
# <a href="https://colab.research.google.com/github/H0E0M0A0N0T0/Ai-ml-lab-sheets-/blob/main/LabSheet_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
yield_Apples=[0.895,0.91,0.919,0.926,0.929,0.931]

# %%
years=[2010,2011,2012,2013,2014,2015]
yield_Apples=[0.895,0.91,0.919,0.926,0.929,0.931]
plt.plot(years,yield_Apples)

# %%
plt.plot(years,yield_Apples)
plt.xlabel('years')
plt.ylabel('yield(tons per hectare)');

# %%
year=range(2000,2008)

apples=[0.895,0.91,0.919,0.926,0.929,0.934,0.936,0.937]
oranges=[0.962,0.941,0.930,0.918,0.908,0.907,0.904,0.901]
plt.plot(year,apples)
plt.plot(year,oranges)
plt.xlabel('year')
plt.ylabel('yield')
# Out:
# Text(0, 0.5, 'yield')

# %%
plt.plot(year,apples)
plt.plot(year,oranges)
plt.xlabel('year')
plt.ylabel('yield')
plt.legend(['apples','oranges'])
plt.title('Crop yield in kanto')
# Out:
# Text(0.5, 1.0, 'Crop yield in kanto')

# %%
plt.plot(year,apples,marker='o')
plt.plot(year,oranges,marker='x')
plt.xlabel('year')
plt.ylabel('yield')
plt.legend(['apples','oranges'])
plt.title('Crop yield in kanto')
# Out:
# Text(0.5, 1.0, 'Crop yield in kanto')

# %%
plt.plot(year,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='navy')
plt.plot(year,oranges,marker='o',c='r',ls='--',lw=2,ms=10,alpha=0.5)
plt.xlabel('years')
plt.ylabel('yield')
plt.legend(['apples','oranges'])
plt.title('Crop yield in kanto')
# Out:
# Text(0.5, 1.0, 'Crop yield in kanto')

# %%
plt.plot(year,apples,'s-b')
plt.plot(year,oranges,'o--r')
plt.xlabel('years')
plt.ylabel('yield')
plt.title('Crop yield in kanto')
plt.legend(['apples','oranges'])

# %%
plt.plot(year,apples,'sb')
plt.plot(year,oranges,'or')
plt.xlabel('years')
plt.ylabel('yield')
plt.title('Crop yield in kanto')
plt.legend(['apples','oranges'])

# %%
x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]
plt.bar(x,y)
plt.title("Bar Chart")
plt.legend(["Bar"])
plt.show()

# %%
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.legend(["A"])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x=[1,2,3,4]
e=[0.1,0,0,0]
plt.pie(x, explode=e)
plt.title("Pie Chart")
plt.show()
